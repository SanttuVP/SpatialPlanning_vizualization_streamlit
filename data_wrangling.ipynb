# %%
import pandas as pd
import geopandas as gpd
import streamlit as st

# %%
gdf = gpd.read_file("http://pygeoapi-testing.gispocoding.fi/collections/koonti_koko_suomi_kaavakohteet/items?f=json&limit=1000")

# %%
gdf['kaavoitusteema'] = gdf['kaavoitusteema'].astype('str')
gdf['kaavamaarayslaji'] = gdf['kaavamaarayslaji'].astype('str')
gdf.head()
# Out:
#    fid    id  koonti_id  id_kaava  id_kaavakohde      kaavoitusteema  \
# 0    1  12.0          1         2             12               Kadut
# 1    2  13.0          1         2             15               Kadut
# 2    3  14.0          1         2              4  Muu kaavoitusteema
# 3    4  15.0          1         2              7               Kadut
# 4    5  16.0          1         2             21               Kadut
#
#             kaavamaarayslaji         tekstiarvo  numeerinen_arvo mittayksikko  \
# 0        Kadun tai tien nimi  Lounaistuulenkuja              NaN         None
# 1        Kadun tai tien nimi        Sammonsilta             12.5            m
# 2  Torin tai katuaukion nimi     Merituulentori              NaN         None
# 3        Kadun tai tien nimi    Neljäntuulentie             10.5            m
# 4        Kadun tai tien nimi      Itätuulenkuja              8.0            m
#
#    tietoyksikko_nimi sitovuuslaji maanalaisuuden_laji st_asgeojson  \
# 0  Lounaistuulenkuja       Sitova       Maanpäällinen         None
# 1        Sammonsilta       Sitova       Maanpäällinen         None
# 2     Merituulentori       Sitova       Maanpäällinen         None
# 3  Neljäntuulensilta       Sitova       Maanpäällinen         None
# 4      Itätuulenkuja       Sitova       Maanpäällinen         None
#
#                                             geometry
# 0  MULTIPOLYGON Z (((24.80178 60.17420 0.00000, 2...
# 1  MULTIPOLYGON Z (((24.80297 60.17419 0.00000, 2...
# 2  MULTIPOLYGON Z (((24.80205 60.17484 0.00000, 2...
# 3  MULTIPOLYGON Z (((24.80149 60.17472 0.00000, 2...
# 4  MULTIPOLYGON Z (((24.80179 60.17391 0.00000, 2...

# %%
mask = gdf["kaavamaarayslaji"].str.contains("asuin", case=False, na=False)
gdf[mask]
# Out:
#      fid     id  koonti_id  id_kaava  id_kaavakohde kaavoitusteema  \
# 109  110  130.0          1         2              6       Asuminen
# 110  111  131.0          1         2              9       Asuminen
# 111  112  132.0          1         2             10       Asuminen
# 112  113  133.0          1         2             11       Asuminen
# 113  114  134.0          1         2             12       Asuminen
# 114  115  135.0          1         2             14       Asuminen
# 115  116  136.0          1         2             15       Asuminen
# 116  117  137.0          1         2             16       Asuminen
# 117  118  138.0          1         2             17       Asuminen
# 118  119  139.0          1         2             19       Asuminen
# 119  120  140.0          1         2             20       Asuminen
# 120  121  142.0          1         2             37       Asuminen
# 235  236   28.0          2         1              5       Asuminen
# 236  237   29.0          2         1              6       Asuminen
# 237  238   30.0          2         1              7       Asuminen
# 238  239   31.0          2         1              8       Asuminen
# 239  240   32.0          2         1              9       Asuminen
# 240  241   33.0          2         1             10       Asuminen
# 241  242   34.0          2         1             11       Asuminen
# 242  243   35.0          2         1             12       Asuminen
# 243  244   36.0          2         1             14       Asuminen
# 244  245   38.0          2         1             15       Asuminen
# 284  285   78.0          2         1             13       Asuminen
#
#         kaavamaarayslaji                                        tekstiarvo  \
# 109  Asuinkerrostaloalue                                              None
# 110  Asuinkerrostaloalue                                              None
# 111  Asuinkerrostaloalue                                              None
# 112  Asuinkerrostaloalue                                              None
# 113  Asuinkerrostaloalue                                              None
# 114  Asuinkerrostaloalue                                              None
# 115  Asuinkerrostaloalue                                              None
# 116  Asuinkerrostaloalue  Alueelle ei saa sijoittaa asuntokohtaisia pihoja
# 117  Asuinkerrostaloalue                                              None
# 118  Asuinkerrostaloalue                                              None
# 119  Asuinkerrostaloalue                                              None
# 120  Asuinkerrostaloalue                                              None
# 235    Asuinpientaloalue                                              None
# 236    Asuinpientaloalue                                              None
# 237    Asuinpientaloalue                                              None
# 238    Asuinpientaloalue                                              None
# 239    Asuinpientaloalue                                              None
# 240    Asuinpientaloalue                                              None
# 241    Asuinpientaloalue                                              None
# 242    Asuinpientaloalue                                              None
# 243    Asuinpientaloalue                                              None
# 244    Asuinpientaloalue                                              None
# 284    Asuinpientaloalue                                              None
#
#      numeerinen_arvo mittayksikko             tietoyksikko_nimi sitovuuslaji  \
# 109              NaN         None                          None       Sitova
# 110              NaN         None                          None       Sitova
# 111              NaN         None                          None       Sitova
# 112              NaN         None                          None       Sitova
# 113              NaN         None                          None       Sitova
# 114              NaN         None                          None       Sitova
# 115              NaN         None                          None       Sitova
# 116              NaN         None  Alueelle ei saa sijoittaa...       Sitova
# 117              NaN         None                          None       Sitova
# 118              NaN         None                          None       Sitova
# 119              NaN         None                          None       Sitova
# 120              NaN         None                          None       Sitova
# 235              NaN         None                          None       Sitova
# 236              NaN         None                          None       Sitova
# 237              NaN         None                          None       Sitova
# 238              NaN         None                          None       Sitova
# 239              NaN         None                          None       Sitova
# 240              NaN         None                          None       Sitova
# 241              NaN         None                          None       Sitova
# 242              NaN         None                          None       Sitova
# 243              NaN         None                          None       Sitova
# 244              NaN         None                          None       Sitova
# 284              NaN         None                          None       Sitova
#
#     maanalaisuuden_laji st_asgeojson  \
# 109       Maanpäällinen         None
# 110       Maanpäällinen         None
# 111       Maanpäällinen         None
# 112       Maanpäällinen         None
# 113       Maanpäällinen         None
# 114       Maanpäällinen         None
# 115       Maanpäällinen         None
# 116       Maanpäällinen         None
# 117       Maanpäällinen         None
# 118       Maanpäällinen         None
# 119       Maanpäällinen         None
# 120       Maanpäällinen         None
# 235       Maanpäällinen         None
# 236       Maanpäällinen         None
# 237       Maanpäällinen         None
# 238       Maanpäällinen         None
# 239       Maanpäällinen         None
# 240       Maanpäällinen         None
# 241       Maanpäällinen         None
# 242       Maanpäällinen         None
# 243       Maanpäällinen         None
# 244       Maanpäällinen         None
# 284       Maanpäällinen         None
#
#                                               geometry
# 109  MULTIPOLYGON Z (((24.80195 60.17478 0.00000, 2...
# 110  MULTIPOLYGON Z (((24.80168 60.17438 0.00000, 2...
# 111  MULTIPOLYGON Z (((24.80170 60.17434 0.00000, 2...
# 112  MULTIPOLYGON Z (((24.80175 60.17426 0.00000, 2...
# 113  MULTIPOLYGON Z (((24.80178 60.17420 0.00000, 2...
# 114  MULTIPOLYGON Z (((24.80227 60.17444 0.00000, 2...
# 115  MULTIPOLYGON Z (((24.80297 60.17419 0.00000, 2...
# 116  MULTIPOLYGON Z (((24.80253 60.17399 0.00000, 2...
# 117  MULTIPOLYGON Z (((24.80184 60.17409 0.00000, 2...
# 118  MULTIPOLYGON Z (((24.80266 60.17401 0.00000, 2...
# 119  MULTIPOLYGON Z (((24.80297 60.17419 0.00000, 2...
# 120  MULTIPOLYGON Z (((24.80195 60.17391 0.00000, 2...
# 235  MULTIPOLYGON Z (((23.99647 61.29427 0.00000, 2...
# 236  MULTIPOLYGON Z (((23.99714 61.29450 0.00000, 2...
# 237  GEOMETRYCOLLECTION Z (POLYGON Z ((23.99745 61....
# 238  MULTIPOLYGON Z (((23.99896 61.29463 0.00000, 2...
# 239  MULTIPOLYGON Z (((23.99987 61.29578 0.00000, 2...
# 240  MULTIPOLYGON Z (((23.99864 61.29495 0.00000, 2...
# 241  MULTIPOLYGON Z (((24.00032 61.29666 0.00000, 2...
# 242  GEOMETRYCOLLECTION Z (POLYGON Z ((24.00039 61....
# 243  GEOMETRYCOLLECTION Z (POLYGON Z ((23.99980 61....
# 244  MULTIPOLYGON Z (((23.99897 61.29381 0.00000, 2...
# 284  MULTIPOLYGON Z (((24.00081 61.29463 0.00000, 2...

# %%
df = gdf[gdf["kaavamaarayslaji"].str.contains("rakennus")]
df = df[['id_kaava','kaavoitusteema','kaavamaarayslaji', 'numeerinen_arvo', 'mittayksikko']]
df.groupby('id_kaava')['kaavamaarayslaji'].value_counts()
df
# Out:
#      id_kaava kaavoitusteema                                 kaavamaarayslaji  \
# 39          2       Asuminen                          Varastorakennusten alue
# 121         2       Asuminen                            Liikerakennusten alue
# 122         2       Asuminen                            Liikerakennusten alue
# 123         2       Asuminen                            Liikerakennusten alue
# 124         2       Asuminen                            Liikerakennusten alue
# 125         2       Asuminen                            Liikerakennusten alue
# 126         2       Asuminen                            Liikerakennusten alue
# 127         2       Asuminen                            Liikerakennusten alue
# 128         2       Asuminen                            Liikerakennusten alue
# 129         2       Asuminen                            Liikerakennusten alue
# 130         2       Asuminen                            Liikerakennusten alue
# 131         2       Asuminen                            Liikerakennusten alue
# 132         2       Asuminen                            Liikerakennusten alue
# 133         2       Asuminen                            Liikerakennusten alue
# 134         2       Asuminen                         Toimistorakennusten alue
# 135         2       Asuminen                         Toimistorakennusten alue
# 136         2       Asuminen                         Toimistorakennusten alue
# 137         2       Asuminen                         Toimistorakennusten alue
# 138         2       Asuminen                         Toimistorakennusten alue
# 139         2       Asuminen                         Toimistorakennusten alue
# 140         2       Asuminen                         Toimistorakennusten alue
# 141         2       Asuminen                         Toimistorakennusten alue
# 142         2       Asuminen                         Toimistorakennusten alue
# 143         2       Asuminen                         Toimistorakennusten alue
# 144         2       Asuminen                         Toimistorakennusten alue
# 145         2       Asuminen                         Toimistorakennusten alue
# 146         2       Asuminen                         Toimistorakennusten alue
# 147         2       Asuminen                          Palvelurakennusten alue
# 148         2       Asuminen                          Palvelurakennusten alue
# 149         2       Asuminen                          Palvelurakennusten alue
# 150         2       Asuminen                          Palvelurakennusten alue
# 151         2       Asuminen                          Palvelurakennusten alue
# 152         2       Asuminen                          Palvelurakennusten alue
# 153         2       Asuminen                          Palvelurakennusten alue
# 154         2       Asuminen                          Palvelurakennusten alue
# 155         2       Asuminen                          Palvelurakennusten alue
# 156         2       Asuminen                          Palvelurakennusten alue
# 157         2       Asuminen                          Palvelurakennusten alue
# 158         2       Asuminen                          Palvelurakennusten alue
# 159         2       Asuminen                          Palvelurakennusten alue
# 160         2       Asuminen  Kulttuuritoimintaa palvelevien rakennusten alue
# 161         2       Asuminen  Kulttuuritoimintaa palvelevien rakennusten alue
# 162         2       Asuminen  Kulttuuritoimintaa palvelevien rakennusten alue
# 163         2       Asuminen  Kulttuuritoimintaa palvelevien rakennusten alue
# 164         2       Asuminen  Kulttuuritoimintaa palvelevien rakennusten alue
# 165         2       Asuminen  Kulttuuritoimintaa palvelevien rakennusten alue
# 166         2       Asuminen  Kulttuuritoimintaa palvelevien rakennusten alue
# 167         2       Asuminen  Kulttuuritoimintaa palvelevien rakennusten alue
# 168         2       Asuminen  Kulttuuritoimintaa palvelevien rakennusten alue
# 169         2       Asuminen  Kulttuuritoimintaa palvelevien rakennusten alue
# 170         2       Asuminen  Kulttuuritoimintaa palvelevien rakennusten alue
# 171         2       Asuminen  Kulttuuritoimintaa palvelevien rakennusten alue
# 172         2       Asuminen  Kulttuuritoimintaa palvelevien rakennusten alue
#
#      numeerinen_arvo mittayksikko
# 39               NaN         None
# 121              NaN         None
# 122              NaN         None
# 123              NaN         None
# 124              NaN         None
# 125              NaN         None
# 126              NaN         None
# 127              NaN         None
# 128              NaN         None
# 129              NaN         None
# 130              NaN         None
# 131              NaN         None
# 132              NaN         None
# 133              NaN         None
# 134              NaN         None
# 135              NaN         None
# 136              NaN         None
# 137              NaN         None
# 138              NaN         None
# 139              NaN         None
# 140              NaN         None
# 141              NaN         None
# 142              NaN         None
# 143              NaN         None
# 144              NaN         None
# 145              NaN         None
# 146              NaN         None
# 147              NaN         None
# 148              NaN         None
# 149              NaN         None
# 150              NaN         None
# 151              NaN         None
# 152              NaN         None
# 153              NaN         None
# 154              NaN         None
# 155              NaN         None
# 156              NaN         None
# 157              NaN         None
# 158              NaN         None
# 159              NaN         None
# 160              NaN         None
# 161              NaN         None
# 162              NaN         None
# 163              NaN         None
# 164              NaN         None
# 165              NaN         None
# 166              NaN         None
# 167              NaN         None
# 168              NaN         None
# 169              NaN         None
# 170              NaN         None
# 171              NaN         None
# 172              NaN         None

# %%
kadun = gdf.loc[gdf['kaavamaarayslaji'].str.contains("Kadun", case=False)]
kadun
# Out:
# Empty GeoDataFrame
# Columns: [fid, id, koonti_id, id_kaava, id_kaavakohde, kaavoitusteema, kaavamaarayslaji, tekstiarvo, numeerinen_arvo, mittayksikko, tietoyksikko_nimi, sitovuuslaji, maanalaisuuden_laji, geometry]
# Index: []

# %%
gdf.dtypes
# Out:
# fid                       int64
# id                        int64
# koonti_id                 int64
# id_kaava                  int64
# id_kaavakohde             int64
# kaavoitusteema           object
# kaavamaarayslaji         object
# tekstiarvo               object
# numeerinen_arvo         float64
# mittayksikko             object
# tietoyksikko_nimi        object
# sitovuuslaji             object
# maanalaisuuden_laji      object
# geometry               geometry
# dtype: object

# %%
m = leafmap.Map(center=[60.174, 24.802], zoom=14.5, height=600, widescreen=False)

# %%
gdf.head()
# Out:
#    fid    id  koonti_id  id_kaava  id_kaavakohde      kaavoitusteema  \
# 0    1  12.0          1         2             12               Kadut
# 1    2  13.0          1         2             15               Kadut
# 2    3  14.0          1         2              4  Muu kaavoitusteema
# 3    4  15.0          1         2              7               Kadut
# 4    5  16.0          1         2             21               Kadut
#
#             kaavamaarayslaji         tekstiarvo  numeerinen_arvo mittayksikko  \
# 0        Kadun tai tien nimi  Lounaistuulenkuja              NaN         None
# 1        Kadun tai tien nimi        Sammonsilta             12.5            m
# 2  Torin tai katuaukion nimi     Merituulentori              NaN         None
# 3        Kadun tai tien nimi    Neljäntuulentie             10.5            m
# 4        Kadun tai tien nimi      Itätuulenkuja              8.0            m
#
#    tietoyksikko_nimi sitovuuslaji maanalaisuuden_laji st_asgeojson  \
# 0  Lounaistuulenkuja       Sitova       Maanpäällinen         None
# 1        Sammonsilta       Sitova       Maanpäällinen         None
# 2     Merituulentori       Sitova       Maanpäällinen         None
# 3  Neljäntuulensilta       Sitova       Maanpäällinen         None
# 4      Itätuulenkuja       Sitova       Maanpäällinen         None
#
#                                             geometry
# 0  MULTIPOLYGON Z (((24.80178 60.17420 0.00000, 2...
# 1  MULTIPOLYGON Z (((24.80297 60.17419 0.00000, 2...
# 2  MULTIPOLYGON Z (((24.80205 60.17484 0.00000, 2...
# 3  MULTIPOLYGON Z (((24.80149 60.17472 0.00000, 2...
# 4  MULTIPOLYGON Z (((24.80179 60.17391 0.00000, 2...

# %%
m.add_gdf(gdf, layer_name="Pyoratiet")
